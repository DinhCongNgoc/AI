# %% [markdown]
# <a href="https://colab.research.google.com/github/DinhCongNgoc/AI/blob/main/Ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #Khai báo thư viện Numpy là np
import os #Đọc địa chỉ ảnh
from PIL import Image #Xử lý vẽ ảnh
import matplotlib.pyplot as plt # thư viện dùng để vẽ
from keras.models import Sequential # hàm chạy mô hình
from keras.layers import Dense,Activation,Dropout # tạo mạng nơ ron
from tensorflow.keras.optimizers import RMSprop # tạo thuật toán training
from keras.callbacks import EarlyStopping #dừng training khi models training không hiệu quả
from keras.backend import categorical_crossentropy

# %%
#Khai báo biến đọc địa chỉ
train_data ='drive/MyDrive/Baitapvenha/training'
validation_data='drive/MyDrive/Baitapvenha/validation'
test_data='drive/MyDrive/Baitapvenha/test'

# %%
listdata_train=[]
listdata_validation=[]
listdata_test=[]
dict={'Bao':[0],'Ngoc':[1],'Nhat':[2]}

# %%
def Getdata(dirdata,lstdata):
#Đọc hình ảnh trong tập dữ liệu
  for whatever in os.listdir(dirdata):
      whatever_path = os.path.join(dirdata,whatever)
      lst_filename_path=[]
      for filename in os.listdir(whatever_path):
        filename_path=os.path.join(whatever_path,filename)
        label=filename_path.split('/')[4]
        img = np.array(Image.open(filename_path))
        lst_filename_path.append((img,dict[label]))
      lstdata.extend(lst_filename_path)
  for i in range(3):
      np.random.shuffle(lstdata)
  return lstdata

# %%
listdata_train=Getdata(train_data,listdata_train)
listdata_test=Getdata(test_data,listdata_test)
listdata_validation=Getdata(validation_data,listdata_validation)

# %%
x_train=np.array([x[0] for _ ,x in enumerate(listdata_train)])
y_train=np.array([y[1] for _ ,y in enumerate(listdata_train)])
y_train.shape
# Out:
# (90, 1)

# %%
x_test=np.array([x[0] for _ ,x in enumerate(listdata_test)])
y_test=np.array([y[1] for _ ,y in enumerate(listdata_test)])

# %%
x_validation=np.array([x[0] for _ ,x in enumerate(listdata_validation)])
y_validation=np.array([y[1] for _ ,y in enumerate(listdata_validation)])
x_validation.shape
# Out:
# (4, 256, 256, 3)

# %%
yname=y_train.flatten()

# %%
class_names=['Bao','Ngoc','Nhat']
x_pre=x_test
y_pre=y_test
y_pre
# Out:
# array([[2],
#        [1],
#        [0],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [1],
#        [2],
#        [1],
#        [2],
#        [1],
#        [0],
#        [2],
#        [0],
#        [0],
#        [0],
#        [2],
#        [0],
#        [0],
#        [2],
#        [0],
#        [0],
#        [1],
#        [0],
#        [1],
#        [2],
#        [0],
#        [1],
#        [0],
#        [2],
#        [1],
#        [0],
#        [2],
#        [1],
#        [1],
#        [2],
#        [0],
#        [0],
#        [0],
#        [1],
#        [2],
#        [1],
#        [1],
#        [1],
#        [1],
#        [2],
#        [2],
#        [0],
#        [1],
#        [1],
#        [0],
#        [2],
#        [0],
#        [2],
#        [2]])

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i], cmap='binary')
    plt.xlabel(class_names[yname[i]])
plt.show()

# %%
from keras.utils import np_utils
x_train=x_train.reshape(90,196608)
x_test=x_test.reshape(57,196608)
x_validation=x_validation.reshape(4,196608)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')
x_validation=x_validation.astype('float32')
x_train/=255
x_test/=255
x_validation/=255
y_train=np_utils.to_categorical(y_train,3)
y_test= np_utils.to_categorical(y_test,3)
y_validation= np_utils.to_categorical(y_validation,3)

# %%
model=Sequential()
model.add(Dense(1000,activation='relu',input_shape=(196608,)))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 1000)              196609000
#
#  dense_28 (Dense)            (None, 512)               512512
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_29 (Dense)            (None, 3)                 1539
#
# =================================================================
# Total params: 197,123,051
# Trainable params: 197,123,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history=model.fit
120
# 1/1 [==============================] - 2s 2s/step - loss: 6.5128 - accuracy: 0.7556 - val_loss: 24.1447 - val_accuracy: 0.5000
# Epoch 23/120
# 1/1 [==============================] - 2s 2s/step - loss: 12.2862 - accuracy: 0.6556 - val_loss: 17.3537 - val_accuracy: 0.5000
# Epoch 24/120
# 1/1 [==============================] - 2s 2s/step - loss: 8.0214 - accuracy: 0.7889 - val_loss: 4.9643 - val_accuracy: 0.7500
# Epoch 25/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.8150 - accuracy: 0.7889 - val_loss: 3.6621 - val_accuracy: 0.7500
# Epoch 26/120
# 1/1 [==============================] - 2s 2s/step - loss: 10.3112 - accuracy: 0.7333 - val_loss: 8.9407e-08 - val_accuracy: 1.0000
# Epoch 27/120
# 1/1 [==============================] - 2s 2s/step - loss: 4.2949 - accuracy: 0.8333 - val_loss: 4.4107e-06 - val_accuracy: 1.0000
# Epoch 28/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.4057 - accuracy: 0.8778 - val_loss: 2.2474 - val_accuracy: 0.7500
# Epoch 29/120
# 1/1 [==============================] - 2s 2s/step - loss: 5.0069 - accuracy: 0.8778 - val_loss: 5.4697 - val_accuracy: 0.5000
# Epoch 30/120
# 1/1 [==============================] - 2s 2s/step - loss: 5.2579 - accuracy: 0.8444 - val_loss: 1.6179 - val_accuracy: 0.7500
# Epoch 31/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.9420 - accuracy: 0.8444 - val_loss: 8.0466e-07 - val_accuracy: 1.0000
# Epoch 32/120
# 1/1 [==============================] - 2s 2s/step - loss: 3.9550 - accuracy: 0.8556 - val_loss: 2.3842e-07 - val_accuracy: 1.0000
# Epoch 33/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.0975 - accuracy: 0.8889 - val_loss: 1.7881e-07 - val_accuracy: 1.0000
# Epoch 34/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.5416 - accuracy: 0.9111 - val_loss: 0.3817 - val_accuracy: 0.7500
# Epoch 35/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.9624 - accuracy: 0.9444 - val_loss: 2.6690 - val_accuracy: 0.7500
# Epoch 36/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.8914 - accuracy: 0.9333 - val_loss: 3.2555 - val_accuracy: 0.7500
# Epoch 37/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.1268 - accuracy: 0.9111 - val_loss: 0.6293 - val_accuracy: 0.7500
# Epoch 38/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.6730 - accuracy: 0.9000 - val_loss: 5.4538e-06 - val_accuracy: 1.0000
# Epoch 39/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.3653 - accuracy: 0.9333 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 40/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.4728 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 41/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.7396 - accuracy: 0.9667 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 42/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3222 - accuracy: 0.9667 - val_loss: 6.4074e-06 - val_accuracy: 1.0000
# Epoch 43/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3320 - accuracy: 0.9889 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 44/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3368 - accuracy: 0.9556 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 45/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.4490 - accuracy: 0.9556 - val_loss: 1.0309e-04 - val_accuracy: 1.0000
# Epoch 46/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.6001 - accuracy: 0.9556 - val_loss: 7.3909e-06 - val_accuracy: 1.0000
# Epoch 47/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3904 - accuracy: 0.9778 - val_loss: 1.7285e-06 - val_accuracy: 1.0000
# Epoch 48/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.8743e-07 - val_accuracy: 1.0000
# Epoch 49/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1429 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 50/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1353 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 51/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3029 - accuracy: 0.9667 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 52/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.3673 - accuracy: 0.9778 - val_loss: 8.9407e-07 - val_accuracy: 1.0000
# Epoch 53/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.6680 - accuracy: 0.9778 - val_loss: 1.3709e-06 - val_accuracy: 1.0000
# Epoch 54/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1348 - accuracy: 0.9889 - val_loss: 4.4703e-07 - val_accuracy: 1.0000
# Epoch 55/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 4.7684e-07 - val_accuracy: 1.0000
# Epoch 56/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0483 - accuracy: 0.9889 - val_loss: 5.9605e-08 - val_accuracy: 1.0000
# Epoch 57/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1314 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 58/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1761 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 59/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.2405e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 60/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1975 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 61/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0445 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 62/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0834 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 63/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0238 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 64/120
# 1/1 [==============================] - 5s 5s/step - loss: 3.9736e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 65/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 5.9605e-08 - val_accuracy: 1.0000
# Epoch 66/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1256 - accuracy: 0.9556 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 67/120
# 1/1 [==============================] - 2s 2s/step - loss: 5.1934e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 68/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1945 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 69/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.1606e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 70/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0223 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 71/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 72/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.0939e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 73/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0751 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 74/120
# 1/1 [==============================] - 2s 2s/step - loss: 7.1392e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 75/120
# 1/1 [==============================] - 2s 2s/step - loss: 4.9953e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 76/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0577 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 77/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.4225e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 78/120
# 1/1 [==============================] - 2s 2s/step - loss: 7.7699e-05 - accuracy: 1.0000 - val_loss: 8.9407e-08 - val_accuracy: 1.0000
# Epoch 79/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0224 - accuracy: 0.9889 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 80/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0667 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 81/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 82/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 83/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.4248e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 84/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.1342 - accuracy: 0.9778 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 85/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.0094e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 86/120
# 1/1 [==============================] - 2s 2s/step - loss: 7.9473e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 87/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.9868e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 88/120
# 1/1 [==============================] - 2s 2s/step - loss: 9.9341e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 89/120
# 1/1 [==============================] - 2s 2s/step - loss: 4.2253e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 90/120
# 1/1 [==============================] - 2s 2s/step - loss: 5.2982e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 91/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0946 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 92/120
# 1/1 [==============================] - 2s 2s/step - loss: 7.3887e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 93/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.1058e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 94/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.3047e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 95/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 96/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.6009e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 97/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0795 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 98/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0304 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 99/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.4739e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 100/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 101/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.3245e-09 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 102/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 103/120
# 1/1 [==============================] - 2s 2s/step - loss: 3.2925e-04 - accuracy: 1.0000 - val_loss: 1.1921e-07 - val_accuracy: 1.0000
# Epoch 104/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0215 - accuracy: 0.9889 - val_loss: 2.9802e-08 - val_accuracy: 1.0000
# Epoch 105/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.0199e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 106/120
# 1/1 [==============================] - 2s 2s/step - loss: 1.5232e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 107/120
# 1/1 [==============================] - 2s 2s/step - loss: 5.4675e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 108/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.0410e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 109/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.0573e-04 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 110/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 111/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0524 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 112/120
# 1/1 [==============================] - 2s 2s/step - loss: 3.0465e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 113/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.3842e-08 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 114/120
# 1/1 [==============================] - 2s 2s/step - loss: 2.8678e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 115/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0249 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 116/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0556 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 117/120
# 1/1 [==============================] - 2s 2s/step - loss: 6.4504e-07 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 118/120
# 1/1 [==============================] - 2s 2s/step - loss: 4.1884e-05 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 119/120
# 1/1 [==============================] - 2s 2s/step - loss: 0.0269 - accuracy: 0.9889 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 120/120
# 1/1 [==============================] - 2s 2s/step - loss: 3.2937e-06 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
Score=model.evaluate(x_test,y_test,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 8.54961109161377
# Test accuary 0.7543859481811523

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy and val_accuracy')
plt.xlabel('epochs')
plt.legend(['train','test'])
plt.show()

# %%
plt.figure(figsize=(20, 20))
for i in range(40):
    plt.subplot(10, 4, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_pre[i], cmap='binary')
    plt.title("Model dự đoán là: " + str(class_names[np.argmax(model.predict(x_pre[i].reshape((-1,196608))))]))
plt.show()
