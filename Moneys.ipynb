# %% [markdown]
# <a href="https://colab.research.google.com/github/DinhCongNgoc/AI/blob/main/Moneys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten, Dense,Dropout

# %%
model = Sequential()
model.add(Conv2D(128,(3,3),input_shape=(150,150,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(11,activation ='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 148, 148, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        36896
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# ...
# Total params: 5,350,443
# Trainable params: 5,350,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import drive
drive.mount("/content/gdrive",force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "gdrive/MyDrive/Moneys"
# Out:
# /content/gdrive/MyDrive/Moneys

# %%
# %ls
# Out:
# Final.h5  test/  train/  validation/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %%
training_set=train_datagen.flow_from_directory('/content/gdrive/MyDrive/Moneys/train',target_size=(150,150),batch_size=32,class_mode='categorical')
# Out:
# Found 220 images belonging to 11 classes.

# %%
test_set=train_datagen.flow_from_directory('/content/gdrive/MyDrive/Moneys/test',target_size=(150,150),batch_size=32,class_mode='categorical')
# Out:
# Found 110 images belonging to 11 classes.

# %%
history=model.fit(training_set,epochs=100,validation_data=test_set,verbose=1)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 180s 25s/step - loss: 2.8742 - accuracy: 0.1000 - val_loss: 2.3980 - val_accuracy: 0.1091
# Epoch 2/100
# 7/7 [==============================] - 2s 328ms/step - loss: 2.3980 - accuracy: 0.0955 - val_loss: 2.3975 - val_accuracy: 0.1182
# Epoch 3/100
# 7/7 [==============================] - 2s 337ms/step - loss: 2.3970 - accuracy: 0.0955 - val_loss: 2.3957 - val_accuracy: 0.1364
# Epoch 4/100
# 7/7 [==============================] - 2s 354ms/step - loss: 2.4080 - accuracy: 0.0864 - val_loss: 2.3898 - val_accuracy: 0.1727
# Epoch 5/100
# 7/7 [==============================] - 2s 337ms/step - loss: 2.3915 - accuracy: 0.1273 - val_loss: 2.3688 - val_accuracy: 0.1364
# Epoch 6/100
# 7/7 [==============================] - 2s 335ms/step - loss: 2.3683 - accuracy: 0.1636 - val_loss: 2.3066 - val_accuracy: 0.0909
# Epoch 7/100
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/200VND/2.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [6]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/500VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [10]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/1000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [2]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/2000VND/2.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [5]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/5000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc47f3eba70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [9]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/10000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc47f32c7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [1]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/20000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [4]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/50000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [8]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/100000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [0]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/200000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [3]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Moneys/validation/500000VND/1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [7]
