# %% [markdown]
# <a href="https://colab.research.google.com/github/DinhCongNgoc/AI/blob/main/10fruits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Flatten, Dense,Dropout

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
model = Sequential()
model.add(Conv2D(128,(3,3),input_shape=(256,256,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32,(3,3),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation ='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 254, 254, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      36896
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 123008)            0
#
#  dense (Dense)               (None, 128)               15745152
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 15,786,922
# Trainable params: 15,786,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import drive
drive.mount("/content/gdrive",force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "gdrive/MyDrive/Traicay"
# Out:
# /content/gdrive/MyDrive/Traicay

# %%
# %ls
# Out:
# Final.h5  test/  train/  validation/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# %%
training_set=train_datagen.flow_from_directory('/content/gdrive/MyDrive/Traicay/train',target_size=(256,256),batch_size=32,class_mode='categorical')
# Out:
# Found 300 images belonging to 10 classes.

# %%
test_set=train_datagen.flow_from_directory('/content/gdrive/MyDrive/Traicay/test',target_size=(256,256),batch_size=32,class_mode='categorical')
# Out:
# Found 300 images belonging to 10 classes.

# %%
history=model.fit(training_set,epochs=100,validation_data=test_set,verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 188s 18s/step - loss: 3.0940 - accuracy: 0.1167 - val_loss: 2.2150 - val_accuracy: 0.1700
# Epoch 2/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.1429 - accuracy: 0.1967 - val_loss: 1.9929 - val_accuracy: 0.2700
# Epoch 3/100
# 10/10 [==============================] - 13s 1s/step - loss: 2.0034 - accuracy: 0.2600 - val_loss: 1.8605 - val_accuracy: 0.2900
# Epoch 4/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.8706 - accuracy: 0.3233 - val_loss: 1.6915 - val_accuracy: 0.4033
# Epoch 5/100
# 10/10 [==============================] - 12s 1s/step - loss: 1.7751 - accuracy: 0.3733 - val_loss: 1.6173 - val_accuracy: 0.4567
# Epoch 6/100
# 10/10 [==============================] - 13s 1s/step - loss: 1.7036 - accuracy: 0.4233 - val_loss: 1.4777 - val_accuracy: 0.5200
# Epoch 7/100
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/buoi/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [0]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/cam/image 10.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [1]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/chuoi/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [2]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/xoai/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [9]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/dudu/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f487abee5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [4]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/duahau/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f487ab25200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [3]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/ot/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [7]

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from keras import models
import matplotlib.pyplot as plt 
import matplotlib.image as img
model.save('Final.h5')
model_CNN=models.load_model('Final.h5')
test_image = image.load_img('/content/gdrive/MyDrive/Traicay/validation/traidua/image 1.jpg')
plt.imshow(test_image)
img = image.img_to_array(test_image)
img = img.reshape(1,256,256,3)
img = img.astype('float32')
img = img/255
x = np.argmax(model_CNN.predict(img),axis=1)
print(x)
# Out:
# [8]

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>
